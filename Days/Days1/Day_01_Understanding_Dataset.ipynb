# %%
#how to import libary

# %%
import pandas as pd
data = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Python/Real Estate Property Data Analysis Using Excel.xlsx")

# %% [markdown]
# #undersandanig dataset Head and TAil

# %% [markdown]
# ####undersandanig dataset Head

# %%
data.head()

# %% [markdown]
# #undersand dataset

# %% [markdown]
# ####undersanding dataset for Tail

# %%
data.tail()

# %%
data.sample(5)

# %% [markdown]
# ###show the display as shape

# %%
data.shape
# Out:
# (300, 7)

# %% [markdown]
# ###this dataset is 300 rows and 7 clomuns

# %%
data.columns

# %% [markdown]
# ###Display data types

# %%
data.dtypes

# %% [markdown]
# ###general of dataset summary

# %%
data.info()

# %%
data.describe()

# %%
data.describe(include="all")
